# %% [markdown]
# # NAT Transversal
# ## Clasificar el tipo de NAT de los integrantes

# %% [markdown]
# ### Introducción

# %% [markdown]
# Se va a tratar de averiguar el tipo NAT de cada uno de los integrantes. Para ello el equipo llevó a cabo el siguiente experimento haciendo uso del programa InterCom y de los comandos propios de minimal.py.

# %% [markdown]
# ### Paso 1: establecer "conexión" en una dirección

# %% [markdown]
# Los integrantes intentarán comunicarse una primera vez mandándose paquetes entre sí siguiendo el orden presentado a continuación:
#
# ![directo.png](attachment:ee7a1846-27df-4512-a3a2-a15438863b62.png)
# Los comandos utilizados para esta etapa son:

# %%
python minimal.py -a [IP pública] --show_stats

# %% [raw]
# De esta primera fase se obtuvo como resultado que ninguno de los integrantes recibió los paquetes que se le estaban enviando, es decir, la comunicación no fue exitosa.
#
# **Manuel**
# <br>![captura 1 (Yo a Gyo).png](data:image/png;base64,...)
#
# **Giovanna**
# <br>![carrusel 1_Manu a mi.png](data:image/png;base64,...)
#
# **Mary**
# <br>![Captura de pantalla (1966).png](data:image/png;base64,...)
#
# **Oliver**
# <br>![a.png](data:image/png;base64,...)

# %% [markdown]
# ### Paso 2: establecer "conexión" en dirección inversa

# %% [markdown]
# Los integrantes intentarán comunicarse una segunda vez mandando paquetes siguiendo el orden inverso al que se siguió anteriormente:
#
# ![inverso.png](attachment:e629597d-6450-4479-a44c-6ab79efcf5ac.png)
#
# Los comandos utilizados en esta etapa son:

# %%
python minimal.py -a [IP pública] --show_stats

# %% [markdown]
# En esta segunda fase sí se obtuvo un resultado satisfactorio ya que todos los integrantes recibían los paquetes de la persona que le hablaba.
# Además, utilizando la opción --show_stats se pudo comprobar que todo funcionaba como era esperado.
#
# Se hizo una comprobación extra utilizando una palabra clave que solo conocía el miembro que la pronunciaba, como esta palabra volvio al integrante original se corroboró que el circulo estaba cerrado.
#
# **Manuel**
# <br>![Intento final, cambios rápidos de comunicación con gyo a comunicación con oliver.png](data:image/png;base64,...)
#
# **Giovanna**
# <br>![carrusel 2_Yo a Manu.png](data:image/png;base64,...)
#
# **Mary**
# <br>![Captura de pantalla (1967).png](data:image/png;base64,...)
#
# **Oliver**
# <br>![b.png](data:image/png;base64,...)

# %% [markdown]
# ### Conclusión

# %% [markdown]
# Debido a los resultados obtenidos pensamos que todos los integrantes tienen una NAT de tipo "cono restringido", puesto que todos rechazaron los paquetes entrantes de una red no esperada en el paso 1, pero posteriormente en el paso 2 los paquetes provenientes de la red con la que hace escasos segundos se habían intentado comunicar sí fueron recibidos.
